# %%
import time
import sys
import smtplib
import datetime
from bs4 import BeautifulSoup
from email.mime.text import MIMEText
from pretty_html_table import build_table
import pandas as pd
from smtplib import SMTP
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from datetime import datetime
now = datetime.now()
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
current_date=now.strftime("%d-%m-%Y")




employees=pd.read_csv("friends.csv")
for ind in employees.index:
    TO=employees['Email'][ind]
    id=employees['ID'][ind]  
    df = pd.DataFrame(columns = ['State','District','Pincode','Center', 'Date','Seats','Vaccine','Age Limit'])
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36'}

    url='https://cdn-api.co-vin.in/api/v2/appointment/sessions/public/calendarByDistrict?district_id={}&date={}'.format(id,current_date)
    res=requests.get(url,headers=headers)
    results=res.json()
    for i in range(0,len(results['centers'])):
        center=results['centers'][i]['name']
        state=results['centers'][i]['state_name']
        district=results['centers'][i]['district_name']
        pincode=results['centers'][i]['pincode']
        print(state)
        for j in range(0,len(results['centers'][i]['sessions'])):
            date=results['centers'][i]['sessions'][j]['date']
            seats=results['centers'][i]['sessions'][j]['available_capacity']
            vaccine=results['centers'][i]['sessions'][j]['vaccine']
            age_limit=results['centers'][i]['sessions'][j]['min_age_limit']
            if(seats>0):
                if(age_limit==18):
                    df = df.append({'State':state,'District':district,'Pincode':pincode,'Center' : center, 'Date' : date,'Seats':seats , 'Vaccine' : vaccine, 'Age Limit':age_limit}, 
                    ignore_index = True)
        print('--------------------------------')  
    if len(df)>0:    
        username = ''#enter your email
        password = ''#enter your password
        FROM = ''#enter your email
        Subject = 'Top 5 Economies of the World!'
        msg = MIMEMultipart()

        a=build_table(df, 'blue_light')
        message = MIMEMultipart()
        message['Subject']='Covid slots'
        message.attach(MIMEText(a, "html"))
        msg_body = message.as_string()
        server = smtplib.SMTP('smtp.gmail.com:587')
        server.ehlo()
        server.starttls()
        server.login(username,password)
        server.sendmail(FROM,TO,msg_body)
        server.quit()
        
employees=pd.read_csv("friends2.csv")
for ind in employees.index:
    TO=employees['Email'][ind]
    id=employees['ID'][ind]  
    df = pd.DataFrame(columns = ['State','District','Pincode','Center', 'Date','Seats','Vaccine','Age Limit'])
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36'}
    url='https://cdn-api.co-vin.in/api/v2/appointment/sessions/public/calendarByDistrict?district_id={}&date={}'.format(id,current_date)
    res=requests.get(url,headers=headers)
    results=res.json()
    for i in range(0,len(results['centers'])):
        center=results['centers'][i]['name']
        state=results['centers'][i]['state_name']
        district=results['centers'][i]['district_name']
        pincode=results['centers'][i]['pincode']
        print(state)
        for j in range(0,len(results['centers'][i]['sessions'])):
            date=results['centers'][i]['sessions'][j]['date']
            seats=results['centers'][i]['sessions'][j]['available_capacity']
            vaccine=results['centers'][i]['sessions'][j]['vaccine']
            age_limit=results['centers'][i]['sessions'][j]['min_age_limit']
            if(seats>0):
                if(age_limit==45):
                    df = df.append({'State':state,'District':district,'Pincode':pincode,'Center' : center, 'Date' : date,'Seats':seats , 'Vaccine' : vaccine, 'Age Limit':age_limit}, 
                    ignore_index = True)
        print('--------------------------------')  
    if len(df)>0:    
        username = ''
        password = ''
        FROM = ''
    #     TO = ["nivedita.venkatachalam@latentview.com","prakhar.soni@latentview.com"]
        Subject = 'Top 5 Economies of the World!'
        msg = MIMEMultipart()

        a=build_table(df, 'blue_light')
        message = MIMEMultipart()
        message['Subject']='Covid slots'
        message.attach(MIMEText(a, "html"))
        msg_body = message.as_string()
        server = smtplib.SMTP('smtp.gmail.com:587')
        server.ehlo()
        server.starttls()
        server.login(username,password)
        server.sendmail(FROM,TO,msg_body)
        server.quit()
        


def write_log(text, file):
    f = open(file, 'a')           # 'a' will append to an existing file if it exists
    f.write("{}\n".format(text))  # write the text to the logfile and move to next line
    return 

logfile = r"C:\Users\anirudh.rao.LVCHN\Desktop\vaccination\mylogfile.log"  # name of my log file
               # This will only display to the console
write_log(dt_string, logfile)  # Write the specified text to the logfile
        
        
exit
# Out:
# Tamil Nadu
# --------------------------------
# Tamil Nadu
# --------------------------------
# Tamil Nadu
# --------------------------------
# Tamil Nadu
# --------------------------------
# Tamil Nadu
# --------------------------------
# Tamil Nadu
# --------------------------------
# Telangana
# --------------------------------
# Telangana
# --------------------------------
# Telangana
# --------------------------------
# Telangana
# --------------------------------
# Telangana
# --------------------------------
# Telangana
# --------------------------------
# Telangana
# --------------------------------
# Telangana
# --------------------------------
# Telangana
# --------------------------------
# Telangana
# --------------------------------
# Telangana
# --------------------------------
# Telangana
# --------------------------------
# Telangana
# --------------------------------
# Telangana
# --------------------------------
# Telangana
# --------------------------------
# ...
